# %%
import requests 
from flask import Flask, render_template, request as req

app = Flask(__name__)

@app.route("/", methods=["GET", "POST"])
def Index():
    return render_template("index2.html")

@app.route("/Summarize", methods=["POST"])
def Summarize():
    if req.method == "POST":
        import requests
    
        import requests

        API_URL = "https://api-inference.huggingface.co/models/facebook/bart-large-cnn"
        headers = {"Authorization": "Bearer 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"}

        data = req.form["data"]
        maxL = int(req.form["maxL"])
        minL = maxL // 4

        def query(payload):
            response = requests.post(API_URL, headers=headers, json=payload)
            return response.json()

        output = query({
            "inputs": data,
            "parameters": {"min_length": minL, "max_length": maxL},
        })

        if isinstance(output, list) and len(output) > 0:
            result_text = output[0].get("summary_text", "Summary not found")
        else:
            result_text = "Summary not found"

        return render_template("index2.html", result=result_text)
    else:
        return render_template("index2.html")

if __name__ == '__main__':
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [23/Apr/2024 13:07:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Apr/2024 13:07:20] "GET /static/js/script.js HTTP/1.1" 404 -
# 127.0.0.1 - - [23/Apr/2024 13:07:20] "GET /static/css/jquery-ui.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [23/Apr/2024 13:07:20] "GET /static/css/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [23/Apr/2024 13:07:20] "GET /static/css/responsive.css HTTP/1.1" 304 -
# 127.0.0.1 - - [23/Apr/2024 13:07:20] "GET /static/images/t1.png HTTP/1.1" 304 -
# 127.0.0.1 - - [23/Apr/2024 13:07:20] "GET /static/images/t17.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [23/Apr/2024 13:07:20] "GET /static/images/t18.png HTTP/1.1" 304 -
# 127.0.0.1 - - [23/Apr/2024 13:07:20] "GET /static/images/t21.jpg HTTP/1.1" 304 -
# ...
